# %% [markdown]
# # INPUT

# %%
with open('input.txt', 'r') as file:
    content = file.readlines()

# %% [markdown]
# # PART 1

# %%
counter = 0 
start = 50
for entry in content:
    sgn = 1 if entry[0] == 'R' else -1
    value = int(entry.strip()[1:])

    start = (start + sgn * value) % 100

    if start == 0:
        counter+=1


print(f'Solution: {counter}')
# Out:
# Solution: 1048

# %% [markdown]
# # PART 2

# %%
counter = 0 
start = 50
for entry in content:
    sgn = 1 if entry[0] == 'R' else -1
    value = int(entry.strip()[1:])

    end = (start + sgn * value) % 100
    prev_c = counter

    counter +=  abs((start + sgn * value) // 100)

    if end == 0 and sgn == -1:
        counter += 1
    if start == 0 and sgn == -1:
        counter -=1


    start = end


print(f'Solution: {counter}')
# Out:
# Solution: 6498
